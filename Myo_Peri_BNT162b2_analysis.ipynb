# %% [markdown]
# # **Analysis of "Incidence    Rates of Hospitalisation for Myocarditis and Pericarditis within 30 Days Post-Homologous and Heterologous BNT162b2 Vaccinations among Individuals Younger than 40 Years of Age"**

# %% [markdown]
# **Preparation**

# %% [markdown]
# Install package epiDisplay

# %%
install.packages("epiDisplay")
install.packages("data.table")
install.packages("lubridate")
install.packages("stringr")
install.packages("meta")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘metadat’, ‘numDeriv’, ‘mathjaxr’, ‘pbapply’, ‘minqa’, ‘nloptr’, ‘Rcpp’, ‘RcppEigen’, ‘metafor’, ‘lme4’, ‘CompQuadForm’

# %%
library(tidyverse)
library(epiDisplay)
library(lubridate)
library(stringr)
library(data.table)
library(foreign)
library(readxl)
library(meta)
# Out:
# Loading 'meta' package (version 6.5-0).
# Type 'help(meta)' for a brief overview.
# Readers of 'Meta-Analysis with R (Use R!)' should install
# older version of 'meta' package: https://tinyurl.com/dt4y5drs
#
#
# Attaching package: ‘meta’
#
#
# The following object is masked from ‘package:epiDisplay’:
#
#     ci

# %% [markdown]
# # **Table 1**

# %%
temp <- tempfile()
download.file("https://drive.usercontent.google.com/uc?id=1CwoIGKnXXJPbtsORK_qoC0epT7_AcwHj&authuser=0&export=download", temp)
dem<-read_excel(temp)

# %%
dem<-as.data.table(dem)

# %% [markdown]
# *   age: age group (5–11,12–17,18–40)
# *   m: order of month in cohort

# %%
dem
# Out:
#     status       sex    age   month   m  freq
# 1   infected     Female 5-11  2021-08 M1   8144
# 2   infected     Female 5-11  2021-09 M2   5721
# 3   infected     Female 5-11  2021-10 M3   5749
# 4   infected     Female 12-17 2021-08 M1  11980
# 5   infected     Female 12-17 2021-09 M2   9030
# 6   infected     Female 12-17 2021-10 M3   9159
# 7   infected     Female 18-40 2021-08 M1  99924
# 8   infected     Female 18-40 2021-09 M2  46554
# 9   infected     Female 18-40 2021-10 M3  30193
# 10  infected     Male   5-11  2021-08 M1   8200
# 11  infected     Male   5-11  2021-09 M2   5759
# 12  infected     Male   5-11  2021-10 M3   5560
# 13  infected     Male   12-17 2021-08 M1  12099
# 14  infected     Male   12-17 2021-09 M2   9215
# 15  infected     Male   12-17 2021-10 M3   8603
# 16  infected     Male   18-40 2021-08 M1  91480
# 17  infected     Male   18-40 2021-09 M2  47868
# 18  infected     Male   18-40 2021-10 M3  30839
# 19  SP           Female 5-11  2022-01 M1   3199
# 20  SP           Female 5-11  2022-02 M2   6513
# 21  SP           Female 5-11  2022-03 M3   4824
# 22  SP           Female 12-17 2021-08 M1   8548
# 23  SP           Female 12-17 2021-09 M2  17959
# 24  SP           Female 12-17 2021-10 M3  13203
# 25  SP           Female 18-40 2021-08 M1 469747
# 26  SP           Female 18-40 2021-09 M2 693618
# 27  SP           Female 18-40 2021-10 M3 300198
# 28  SP           Male   5-11  2022-01 M1   3467
# 29  SP           Male   5-11  2022-02 M2   7244
# 30  SP           Male   5-11  2022-03 M3   5384
# ⋮   ⋮            ⋮      ⋮     ⋮       ⋮  ⋮
# 151 PZ-PZ-PZ     Male   12-17 2022-03 M1    20892
# 152 PZ-PZ-PZ     Male   12-17 2022-04 M2    61682
# 153 PZ-PZ-PZ     Male   12-17 2022-05 M3   174330
# 154 PZ-PZ-PZ     Male   12-17 2022-06 M4    56969
# 155 PZ-PZ-PZ     Male   12-17 2022-07 M5     1809
# 156 PZ-PZ-PZ     Male   12-17 2022-08 M6    12433
# 157 PZ-PZ-PZ     Male   18-40 2022-03 M1     5254
# 158 PZ-PZ-PZ     Male   18-40 2022-04 M2     7903
# 159 PZ-PZ-PZ     Male   18-40 2022-05 M3     9851
# 160 PZ-PZ-PZ     Male   18-40 2022-06 M4     5663
# 161 PZ-PZ-PZ     Male   18-40 2022-07 M5      780
# 162 PZ-PZ-PZ     Male   18-40 2022-08 M6     4025
# 163 nonimmunized Female 5-11  2019-08 M1  2704751
# 164 nonimmunized Female 5-11  2019-09 M2  2703872
# 165 nonimmunized Female 5-11  2019-10 M3  2703475
# 166 nonimmunized Female 12-17 2019-08 M1  2359728
# 167 nonimmunized Female 12-17 2019-09 M2  2359016
# 168 nonimmunized Female 12-17 2019-10 M3  2356101
# 169 nonimmunized Female 18-40 2019-08 M1 10880327
# 170 nonimmunized Female 18-40 2019-09 M2 10872915
# 171 nonimmunized Female 18-40 2019-10 M3 10863935
# 172 nonimmunized Male   5-11  2019-08 M1  2864959
# 173 nonimmunized Male   5-11  2019-09 M2  2863798
# 174 nonimmunized Male   5-11  2019-10 M3  2863580
# 175 nonimmunized Male   12-17 2019-08 M1  2489968
# 176 nonimmunized Male   12-17 2019-09 M2  2489579
# 177 nonimmunized Male   12-17 2019-10 M3  2487022
# 178 nonimmunized Male   18-40 2019-08 M1 11125047
# 179 nonimmunized Male   18-40 2019-09 M2 11118946
# 180 nonimmunized Male   18-40 2019-10 M3 11110931

# %% [markdown]
# **Sex**

# %%
pop<-dem[status=="nonimmunized" & m == "M1"]
pop$age<-factor(pop$age,levels = c("5-11","12-17","18-40"))
pop_total <-pop %>% group_by(status) %>% summarise(total = sum(freq))
pop_sex <-pop %>% group_by(status,sex) %>% summarise(n = sum(freq))
merge(pop_sex,pop_total,by="status",all.x=TRUE) %>% mutate(percent = round(n/total*100,1))
# Out:
# `summarise()` has grouped output by 'status'. You can override using the
# `.groups` argument.
#   status       sex    n        total    percent
# 1 nonimmunized Female 15944806 32424780 49.2
# 2 nonimmunized Male   16479974 32424780 50.8

# %%
dem<-dem[status != "nonimmunized"]

# %%
dem$age<-factor(dem$age,levels = c("5-11","12-17","18-40"))

# %%
total<- dem %>% group_by(status) %>% summarise(total = sum(freq))

# %%
dem_sex <- dem %>% group_by(status,sex) %>% summarise(n = sum(freq))
merge(dem_sex,total,by="status",all.x = TRUE) %>% mutate(percent = round(n/total*100,1))
# Out:
# `summarise()` has grouped output by 'status'. You can override using the
# `.groups` argument.
#    status   sex    n       total   percent
# 1  infected Female  226454  446077 50.8
# 2  infected Male    219623  446077 49.2
# 3  PZ       Female 3817627 7594965 50.3
# 4  PZ       Male   3777338 7594965 49.7
# 5  PZ-PZ    Female 3019569 5916836 51.0
# 6  PZ-PZ    Male   2897267 5916836 49.0
# 7  PZ-PZ-PZ Female  666404 1113958 59.8
# 8  PZ-PZ-PZ Male    447554 1113958 40.2
# 9  SP       Female 1517809 2914643 52.1
# 10 SP       Male   1396834 2914643 47.9
# 11 SP-SP    Female 1451540 2782646 52.2
# 12 SP-SP    Male   1331106 2782646 47.8
# 13 SP-SP-PZ Female  689122 1249171 55.2
# 14 SP-SP-PZ Male    560049 1249171 44.8

# %% [markdown]
# **Age**

# %%
pop_age <-pop %>% group_by(status,age) %>% summarise(n = sum(freq))
merge(pop_age,pop_total,by="status",all.x=TRUE) %>% mutate(percent = round(n/total*100,1)) %>% arrange(age)
# Out:
# `summarise()` has grouped output by 'status'. You can override using the
# `.groups` argument.
#   status       age   n        total    percent
# 1 nonimmunized 5-11   5569710 32424780 17.2
# 2 nonimmunized 12-17  4849696 32424780 15.0
# 3 nonimmunized 18-40 22005374 32424780 67.9

# %%
dem_age <- dem %>% group_by(status,age) %>% summarise(n = sum(freq))
merge(dem_age,total,by="status",all.x = TRUE) %>% mutate(percent = round(n/total*100,1)) %>% arrange(status,age)
# Out:
# `summarise()` has grouped output by 'status'. You can override using the
# `.groups` argument.
#    status   age   n       total   percent
# 1  PZ       5-11  2841445 7594965 37.4
# 2  PZ       12-17 3821510 7594965 50.3
# 3  PZ       18-40  932010 7594965 12.3
# 4  PZ-PZ    5-11  2092560 5916836 35.4
# 5  PZ-PZ    12-17 3091247 5916836 52.2
# 6  PZ-PZ    18-40  733029 5916836 12.4
# 7  PZ-PZ-PZ 5-11   191678 1113958 17.2
# 8  PZ-PZ-PZ 12-17  839206 1113958 75.3
# 9  PZ-PZ-PZ 18-40   83074 1113958  7.5
# 10 SP       5-11    30631 2914643  1.1
# 11 SP       12-17   82237 2914643  2.8
# 12 SP       18-40 2801775 2914643 96.1
# 13 SP-SP    5-11    26105 2782646  0.9
# 14 SP-SP    12-17   80326 2782646  2.9
# 15 SP-SP    18-40 2676215 2782646 96.2
# 16 SP-SP-PZ 5-11     7795 1249171  0.6
# 17 SP-SP-PZ 12-17   26960 1249171  2.2
# 18 SP-SP-PZ 18-40 1214416 1249171 97.2
# 19 infected 5-11    39133  446077  8.8
# 20 infected 12-17   60086  446077 13.5
# 21 infected 18-40  346858  446077 77.8

# %% [markdown]
# # **Table 2**

# %% [markdown]
# **Unvaccinated**

# %% [markdown]
# Import data

# %%
temp <- tempfile()
download.file("https://drive.usercontent.google.com/uc?id=1wI17hXr5BpIKNiKfNBoo0_uidNtX_CMh&authuser=0&export=download", temp)
unvac<-readRDS(temp)

# %%
glimpse(unvac)
# Out:
# Rows: 222
# Columns: 9
# $ genid   <chr> "i1", "i2", "i3", "i4", "i5", "i6", "i7", "i8", "i9", "i10", "…
# $ myo     <lgl> TRUE, TRUE, TRUE, TRUE, TRUE, FALSE, TRUE, TRUE, TRUE, TRUE, F…
# $ peri    <lgl> FALSE, FALSE, FALSE, FALSE, FALSE, TRUE, FALSE, FALSE, FALSE, …
# $ sex     <chr> "Female", "Male", "Female", "Female", "Female", "Male", "Male"…
# $ age_y   <int> 40, 13, 23, 35, 29, 33, 10, 38, 14, 40, 39, 7, 37, 28, 7, 5, 9…
# $ age     <fct> 18-40, 12-17, 18-40, 18-40, 18-40, 18-40, 5-11, 18-40, 12-17, …
# $ los     <dbl> 3, 14, 7, 6, 14, 60, 7, 16, 1, 42, 4, 17, 2, 11, 4, 17, 17, 14…
# $ deathdc <chr> "Alive", "Alive", "Alive", "Alive", "Dead", "Alive", "Alive", …
# $ group   <chr> "infected", "infected", "infected", "infected", "infected", "i…

# %% [markdown]
# Myocarditis

# %%
tableStack(sex:deathdc,by=group,data=unvac[myo==TRUE])
# Out:
#               infected        reference  Test stat.           P value
# Total         18              115
#
# sex                                      Chisq. (1 df) = 1.41 0.236
#    Female     7 (38.9)        62 (53.9)
#    Male       11 (61.1)       53 (46.1)
#
# age_y                                    Ranksum test         0.854
#   median(IQR) 18.5 (9.2,33.5) 16 (11,28)
#
# age                                      Chisq. (2 df) = 3.85 0.146
#    5-11       7 (38.9)        31 (27)
#    12-17      2 (11.1)        39 (33.9)
#    18-40      9 (50)          45 (39.1)
#
# los                                      Ranksum test         0.167
#   median(IQR) 9.5 (5.2,15.5)  7 (3.5,11)
#
# deathdc                                  Fisher's exact test  1
#    Alive      16 (88.9)       98 (85.2)
#    Dead       2 (11.1)        17 (14.8)

# %%
paste0(round(by(unvac[myo==TRUE]$age_y,unvac[myo==TRUE]$group,mean),1),"±",round(by(unvac[myo==TRUE]$age_y,unvac[myo==TRUE]$group,sd),1))
# Out:
# [1] "21.2±13.2" "19.4±10.9"

# %% [markdown]
# Pericarditis

# %%
tableStack(sex:deathdc,by=group,data=unvac[peri==TRUE])
# Out:
#               infected   reference  Test stat.                P value
# Total         2          87
#
# sex                                 Fisher's exact test       0.528
#    Female     0 (0)      33 (37.9)
#    Male       2 (100)    54 (62.1)
#
# age_y                               Sample too small: group 1
#   mean(SD)    36 (4.2)   26.5 (7.4)
#
# age                                 Fisher's exact test       1
#    5-11       0 (0)      1 (1.1)
#    12-17      0 (0)      12 (13.8)
#    18-40      2 (100)    74 (85.1)
#
# los                                 Sample too small: group 1
#   median(IQR) 32 (18,46) 5 (3,11)
#
# deathdc                             Fisher's exact test       0.088
#    Alive      1 (50)     84 (96.6)
#    Dead       1 (50)     3 (3.4)

# %% [markdown]
# # **Vaccinated group**

# %%
temp <- tempfile()
download.file("https://drive.google.com/uc?id=1AyL1SfWySwyBmULyphMzN7G-bKiV-WYC&authuser=0&export=download", temp)
vac<-readRDS(temp)

# %% [markdown]
# Myocarditis

# %%
tableStack(sex:deathdc,by=group,data=vac[myo==TRUE])
# Out:
#               pz         pz-pz      pz-pz-pz     sp               sp-sp-pz
# Total         61         144        10           2                3
#
# sex
#    Female     19 (31.1)  43 (29.9)  3 (30)       1 (50)           2 (66.7)
#    Male       42 (68.9)  101 (70.1) 7 (70)       1 (50)           1 (33.3)
#
# age_y
#   median(IQR) 14 (12,15) 14 (12,15) 13.5 (13,16) 22 (21.5,22.5)   19 (19,26)
#
# age
#    5-11       6 (9.8)    5 (3.5)    0 (0)        0 (0)            0 (0)
#    12-17      53 (86.9)  134 (93.1) 9 (90)       0 (0)            0 (0)
#    18-40      2 (3.3)    5 (3.5)    1 (10)       2 (100)          3 (100)
#
# inter
#   median(IQR) 3 (2,10)   3 (1,3)    2.5 (2,3.8)  19.5 (14.2,24.8) 5 (4,12.5)
#
# inter_g
#    0-1        8 (13.1)   40 (27.8)  2 (20)       0 (0)            0 (0)
#    2-7        35 (57.4)  89 (61.8)  6 (60)       0 (0)            2 (66.7)
#    8-30       18 (29.5)  15 (10.4)  2 (20)       2 (100)          1 (33.3)
#
# los
#   median(IQR) 3 (2,5)    3 (2,5)    3.5 (3,6.5)  17.5 (17.2,17.8) 7 (6.5,8)
#
# deathdc
#    Alive      61 (100)   143 (99.3) 10 (100)     2 (100)          3 (100)
#    Dead       0 (0)      1 (0.7)    0 (0)        0 (0)            0 (0)
#
#               Test stat.                P value
# Total
#
# sex           Fisher's exact test       0.62
#    Female
#    Male
#
# age_y         Sample too small: group 4
#   median(IQR)
#
# age           Fisher's exact test       < 0.001
#    5-11
#    12-17
#    18-40
#
# inter         Sample too small: group 4
#   median(IQR)
#
# inter_g       Fisher's exact test       0.002
#    0-1
#    2-7
#    8-30
#
# los           Sample too small: group 4
#   median(IQR)
#
# deathdc       Fisher's exact test       1
#    Alive
#    Dead

# %%
round(by(vac[myo==TRUE]$age_y,vac[myo==TRUE]$group,mean),1)
# Out:
# vac[myo == TRUE]$group: pz
# [1] 13.8
# ------------------------------------------------------------
# vac[myo == TRUE]$group: pz-pz
# [1] 14.3
# ------------------------------------------------------------
# vac[myo == TRUE]$group: pz-pz-pz
# [1] 14.6
# ------------------------------------------------------------
# vac[myo == TRUE]$group: sp
# [1] 22
# ------------------------------------------------------------
# vac[myo == TRUE]$group: sp-sp-pz
# [1] 23.7

# %%
round(by(vac[myo==TRUE]$age_y,vac[myo==TRUE]$group,sd),1)
# Out:
# vac[myo == TRUE]$group: pz
# [1] 2.7
# ------------------------------------------------------------
# vac[myo == TRUE]$group: pz-pz
# [1] 3.5
# ------------------------------------------------------------
# vac[myo == TRUE]$group: pz-pz-pz
# [1] 2.4
# ------------------------------------------------------------
# vac[myo == TRUE]$group: sp
# [1] 1.4
# ------------------------------------------------------------
# vac[myo == TRUE]$group: sp-sp-pz
# [1] 8.1

# %% [markdown]
# Pericarditis

# %%
tab1(vac[peri==TRUE]$group)
# Out:
# vac[peri == TRUE]$group :
#          Frequency Percent Cum. percent
# pz              16      32           32
# pz-pz           29      58           90
# pz-pz-pz         2       4           94
# sp               1       2           96
# sp-sp            1       2           98
# sp-sp-pz         1       2          100
#   Total         50     100          100
# Plot with title “Distribution of vac[peri == TRUE]$group”

# %%
tableStack(sex:deathdc,by=group,data=vac[peri==TRUE & group %in% c("pz","pz-pz")])
# Out:
#               pz             pz-pz     Test stat.             P value
# Total         16             29
#
# sex                                    Fisher's exact test    0.65
#    Female     3 (18.8)       3 (10.3)
#    Male       13 (81.2)      26 (89.7)
#
# age_y                                  t-test  (43 df) = 0.23 0.822
#   mean(SD)    14.8 (2.8)     14.6 (2)
#
# age                                    Fisher's exact test    0.121
#    5-11       1 (6.2)        0 (0)
#    12-17      14 (87.5)      29 (100)
#    18-40      1 (6.2)        0 (0)
#
# inter                                  Ranksum test           0.008
#   median(IQR) 4.5 (3.8,13.2) 2 (1,4)
#
# inter_g                                Fisher's exact test    0.141
#    0-1        1 (6.2)        9 (31)
#    2-7        10 (62.5)      15 (51.7)
#    8-30       5 (31.2)       5 (17.2)
#
# los                                    Ranksum test           0.689
#   median(IQR) 3 (2,4.2)      2 (2,5)
#
# deathdc                                Chisq. (1 df) = 3.76   0.053
#    Alive      16 (100)       29 (100)

# %%
vac[peri==TRUE & group == "pz-pz-pz"]
# Out:
#   genid myo   peri sex  age_y age   inter inter_g los deathdc group
# 1 257   FALSE TRUE Male 16    12-17 7     2-7     5   Alive   pz-pz-pz
# 2 258   FALSE TRUE Male 14    12-17 2     2-7     2   Alive   pz-pz-pz

# %%
vac[peri==TRUE & group == "sp"]
# Out:
#   genid myo  peri sex  age_y age   inter inter_g los deathdc group
# 1 1     TRUE TRUE Male 23    18-40 9     8-30    18  Alive   sp

# %%
vac[peri==TRUE & group == "sp-sp"]
# Out:
#   genid myo   peri sex  age_y age   inter inter_g los deathdc group
# 1 79    FALSE TRUE Male 39    18-40 29    8-30    5   Alive   sp-sp

# %%
vac[peri==TRUE & group == "sp-sp-pz"]
# Out:
#   genid myo   peri sex  age_y age   inter inter_g los deathdc group
# 1 254   FALSE TRUE Male 23    18-40 10    8-30    5   Alive   sp-sp-pz

# %%
round(by(vac[peri==TRUE]$age_y,vac[peri==TRUE]$group,mean),1)
# Out:
# vac[peri == TRUE]$group: pz
# [1] 14.8
# ------------------------------------------------------------
# vac[peri == TRUE]$group: pz-pz
# [1] 14.6
# ------------------------------------------------------------
# vac[peri == TRUE]$group: pz-pz-pz
# [1] 15
# ------------------------------------------------------------
# vac[peri == TRUE]$group: sp
# [1] 23
# ------------------------------------------------------------
# vac[peri == TRUE]$group: sp-sp
# [1] 39
# ------------------------------------------------------------
# vac[peri == TRUE]$group: sp-sp-pz
# [1] 23

# %%
round(by(vac[peri==TRUE]$age_y,vac[peri==TRUE]$group,sd),1)
# Out:
# vac[peri == TRUE]$group: pz
# [1] 2.8
# ------------------------------------------------------------
# vac[peri == TRUE]$group: pz-pz
# [1] 2
# ------------------------------------------------------------
# vac[peri == TRUE]$group: pz-pz-pz
# [1] 1.4
# ------------------------------------------------------------
# vac[peri == TRUE]$group: sp
# [1] NA
# ------------------------------------------------------------
# vac[peri == TRUE]$group: sp-sp
# [1] NA
# ------------------------------------------------------------
# vac[peri == TRUE]$group: sp-sp-pz
# [1] NA

# %% [markdown]
# # **Visualization**

# %%
temp <- tempfile()
download.file("https://drive.usercontent.google.com/uc?id=1M9Cfo3hCOySYX3FrIgVIeE9Qai8yQxRj&authuser=0&export=download", temp)
ref1<-read_excel(temp)

# %%
ref1<-as.data.table(ref1)

# %%
options(repr.plot.width=12, repr.plot.height=9)

# %% [markdown]
# ## **Homologous vaccination**

# %% [markdown]
# **Myocarditis following homologous vaccination**

# %% [markdown]
# Female

# %%
ref1_f<-ref1[status %in% c("PZ","PZ-PZ","PZ-PZ-PZ") & sex == "Female"]
ref1_f$age[ref1_f$age=="5-11"]<-"  5-11"
ref1_f$Age<-paste0(ref1_f$age," yr")
ref1_f$Age<-factor(ref1_f$Age,levels = c("  5-11 yr","12-17 yr","18-40 yr"))
ref1_f<- ref1_f %>% arrange(status,sex,Age)
ref1_f$Dose<-str_count(ref1_f$status,"PZ")

# %%
homo_myo_female_meta<-metainc(event.e=n_myo,
                     time.e=N,
                     event.c=n_myo_c,
                     time.c=N_c,
                     studlab=Age,
                     data=ref1_f,
                     sm="IRR",
                     incr = 0,
                     method ="MH",
                     method.incr = "only0",
                     byvar = Dose,
                     common = TRUE,
                     random = TRUE)

# %%
forest(homo_myo_female_meta,
       order = ref1_f$Age,
       col.square = "green",
       col.square.lines = "green",
       col.diamond.random = "black",
       col.diamond.lines.random = "black",
       allstudies = TRUE,
       text.common = "IRR (fixed)",
       text.random = "IRR (random)",
       leftlabs=c("Dose-age","Event (n)","Total (N•Month)","Event (n)","Total (N•Month)"),
       lab.e="Homologous vaccination",
       lab.c="Reference",
       label.right="Higher risk in vaccine group",
       col.label.right="red",
       label.left="Higher risk in reference group",
       col.label.left="blue",
       hetstat=TRUE,
       digits.mean=2,
       digits.sd=2,
       digits.weight = 0,
       weight.study = "random",
       overall = TRUE,
       col.by="purple",
       addrow.overall=TRUE,
       test.subgroup.common=FALSE,
       test.subgroup.random=FALSE)
# Out:
# plot without title

# %% [markdown]
# Male

# %%
ref1_m<-ref1[ref1$status %in% c("PZ","PZ-PZ","PZ-PZ-PZ") & ref1$sex == "Male",]
ref1_m$Age<-paste0(ref1_m$age," yr")
ref1_m$Age[ref1_m$Age=="5-11 yr"]<-"  5-11 yr"
ref1_m$Age<-factor(ref1_m$Age,levels = c("  5-11 yr","12-17 yr","18-40 yr"))
ref1_m<- ref1_m%>% arrange(status,sex,Age)
ref1_m$Dose<-str_count(ref1_m$status,"PZ")

# %%
homo_myo_male_meta<-metainc(event.e=n_myo,
                     time.e=N,
                     event.c=n_myo_c,
                     time.c=N_c,
                     studlab=Age,
                     data=ref1_m,
                     sm="IRR",
                     incr = 0,
                     method ="MH",
                     method.incr = "only0",
                     byvar = Dose,
                     common = TRUE,
                     random = TRUE)

# %%
forest(homo_myo_male_meta,
       order = ref1_m$Age,
       col.square = "green",
       col.square.lines = "green",
       col.diamond.random = "black",
       col.diamond.lines.random = "black",
       allstudies = TRUE,
       text.common = "IRR (fixed)",
       text.random = "IRR (random)",
       leftlabs=c("Dose-age","Event (n)","Total (N•Month)","Event (n)","Total (N•Month)"),
       lab.e="Homologous vaccination",
       lab.c="Reference",
       label.right="Higher risk in vaccine group",
       col.label.right="red",
       label.left="Higher risk in reference group",
       col.label.left="blue",
       hetstat=TRUE,
       digits.mean=2,
       digits.sd=2,
       digits.weight = 0,
       weight.study = "random",
       overall = TRUE,
       col.by="purple",
       addrow.overall=TRUE,
       test.subgroup.common=FALSE,
       test.subgroup.random=FALSE)
# Out:
# plot without title

# %% [markdown]
# **Pericarditis following homologous vaccination**

# %% [markdown]
# Female

# %%
ref1_f<-ref1[status %in% c("PZ","PZ-PZ","PZ-PZ-PZ") & sex == "Female"]
ref1_f$age[ref1_f$age=="5-11"]<-"  5-11"
ref1_f$Age<-paste0(ref1_f$age," yr")
ref1_f$Age<-factor(ref1_f$Age,levels = c("  5-11 yr","12-17 yr","18-40 yr"))
ref1_f<- ref1_f %>% arrange(status,sex,Age)
ref1_f<-ref1_f[ref1_f$n_peri!= 0 & ref1_f$n_peri_c != 0,]
ref1_f$Dose<-str_count(ref1_f$status,"PZ")

# %%
homo_peri_female_meta<-metainc(event.e=n_peri,
                     time.e=N,
                     event.c=n_peri_c,
                     time.c=N_c,
                     studlab=Age,
                     data=ref1_f,
                     sm="IRR",
                     incr = 0,
                     method ="MH",
                     method.incr = "only0",
                     byvar = Dose,
                     common = TRUE,
                     random = FALSE)

# %%
forest(homo_peri_female_meta,
       order = ref1_f$Age,
       col.square = "green",
       col.square.lines = "green",
       col.diamond.random = "black",
       col.diamond.lines.random = "black",
       allstudies = TRUE,
       text.common = "IRR (fixed)",
       leftlabs=c("Dose-age","Event (n)","Total (N•Month)","Event (n)","Total (N•Month)"),
       lab.e="Homologous vaccination",
       lab.c="Reference",
       label.right="Higher risk in vaccine group",
       col.label.right="red",
       label.left="Higher risk in reference group",
       col.label.left="blue",
       hetstat=TRUE,
       digits.mean=2,
       digits.sd=2,
       digits.weight = 0,
       weight.study = "random",
       overall = TRUE,
       col.by="purple",
       addrow.overall=TRUE,
       test.subgroup.common=FALSE,
       test.subgroup.random=FALSE)
# Out:
# plot without title

# %% [markdown]
# Male

# %%
ref1_m<-ref1[ref1$status %in% c("PZ","PZ-PZ","PZ-PZ-PZ") & ref1$sex == "Male",]
ref1_m$Age<-paste0(ref1_m$age," yr")
ref1_m$Age[ref1_m$Age=="5-11 yr"]<-"  5-11 yr"
ref1_m$Age<-factor(ref1_m$Age,levels = c("  5-11 yr","12-17 yr","18-40 yr"))
ref1_m<- ref1_m%>% arrange(status,sex,Age)
ref1_m$Dose<-str_count(ref1_m$status,"PZ")

# %%
homo_peri_male_meta<-metainc(event.e=n_peri,
                     time.e=N,
                     event.c=n_peri_c,
                     time.c=N_c,
                     studlab=Age,
                     data=ref1_m,
                     sm="IRR",
                     incr = 0,
                     method ="MH",
                     method.incr = "only0",
                     byvar = Dose,
                     common = TRUE,
                     random = TRUE)

# %%
forest(homo_peri_male_meta,
       order = ref1_m$Age,
       col.square = "green",
       col.square.lines = "green",
       col.diamond.random = "black",
       col.diamond.lines.random = "black",
       allstudies = TRUE,
       text.common = "IRR (fixed)",
       text.random = "IRR (random)",
       leftlabs=c("Dose-age","Event (n)","Total (N•Month)","Event (n)","Total (N•Month)"),
       lab.e="Homologous vaccination",
       lab.c="Reference",
       label.right="Higher risk in vaccine group",
       col.label.right="red",
       label.left="Higher risk in reference group",
       col.label.left="blue",
       hetstat=TRUE,
       digits.mean=2,
       digits.sd=2,
       digits.weight = 0,
       weight.study = "random",
       overall = TRUE,
       col.by="purple",
       addrow.overall=TRUE,
       test.subgroup.common=FALSE,
       test.subgroup.random=FALSE)
# Out:
# plot without title

# %% [markdown]
# ## **Heterologous vaccination**

# %% [markdown]
# **Myocarditis following heterologous vaccination**

# %% [markdown]
# Female

# %%
ref1_f<-ref1[ref1$status %in% c("SP","SP-SP","SP-SP-PZ") & ref1$sex == "Female",]
ref1_f$age[ref1_f$age=="5-11"]<-"  5-11"
ref1_f$Age<-paste0(ref1_f$age," yr")
ref1_f$Age<-factor(ref1_f$Age,levels = c("  5-11 yr","12-17 yr","18-40 yr"))
ref1_f<- ref1_f%>% arrange(status,sex,Age)
ref1_f<-ref1_f[ref1_f$n_myo != 0 & ref1_f$n_myo_c != 0,]
ref1_f$Dose<-str_count(ref1_f$status,"-")+1

# %%
hetero_myo_female_meta<-metainc(event.e=n_myo,
                     time.e=N,
                     event.c=n_myo_c,
                     time.c=N_c,
                     studlab=Age,
                     data=ref1_f,
                     sm="IRR",
                     incr = 0,
                     method ="MH",
                     method.incr = "only0",
                     byvar = Dose,
                     common = TRUE,
                     random = TRUE)

# %%
forest(hetero_myo_female_meta,
       order = ref1_f$Age,
       col.square = "green",
       col.square.lines = "green",
       col.diamond.random = "black",
       col.diamond.lines.random = "black",
       allstudies = TRUE,
       text.common = "IRR (fixed)",
       text.random = "IRR (random)",
       leftlabs=c("Dose-age","Event (n)","Total (N•Month)","Event (n)","Total (N•Month)"),
       lab.e="Homologous vaccination",
       lab.c="Reference",
       label.right="Higher risk in vaccine group",
       col.label.right="red",
       label.left="Higher risk in reference group",
       col.label.left="blue",
       hetstat=TRUE,
       digits.mean=2,
       digits.sd=2,
       digits.weight = 0,
       weight.study = "random",
       overall = TRUE,
       col.by="purple",
       addrow.overall=TRUE,
       test.subgroup.common=FALSE,
       test.subgroup.random=FALSE)
# Out:
# plot without title

# %% [markdown]
# Male

# %%
ref1_m<-ref1[ref1$status %in% c("SP","SP-SP","SP-SP-PZ") & ref1$sex == "Male",]
ref1_m$Age<-paste0(ref1_m$age," yr")
ref1_m$Age[ref1_m$Age=="5-11 yr"]<-"  5-11 yr"
ref1_m$Age<-factor(ref1_m$Age,levels = c("  5-11 yr","12-17 yr","18-40 yr"))
ref1_m<- ref1_m%>% arrange(status,sex,Age)
ref1_m<-ref1_m[ref1_m$n_myo != 0 & ref1_m$n_myo_c != 0,]
ref1_m$Dose<-str_count(ref1_m$status,"-")+1

# %%
hetero_myo_male_meta<-metainc(event.e=n_myo,
                     time.e=N,
                     event.c=n_myo_c,
                     time.c=N_c,
                     studlab=Age,
                     data=ref1_m,
                     sm="IRR",
                     incr = 0,
                     method ="MH",
                     method.incr = "only0",
                     byvar = Dose,
                     common = TRUE,
                     random = TRUE)

# %%
forest(hetero_myo_male_meta,
       order = ref1_m$Age,
       col.square = "green",
       col.square.lines = "green",
       col.diamond.random = "black",
       col.diamond.lines.random = "black",
       allstudies = TRUE,
       text.common = "IRR (fixed)",
       text.random = "IRR (random)",
       leftlabs=c("Dose-age","Event (n)","Total (N•Month)","Event (n)","Total (N•Month)"),
       lab.e="Homologous vaccination",
       lab.c="Reference",
       label.right="Higher risk in vaccine group",
       col.label.right="red",
       label.left="Higher risk in reference group",
       col.label.left="blue",
       hetstat=TRUE,
       digits.mean=2,
       digits.sd=2,
       digits.weight = 0,
       weight.study = "random",
       overall = TRUE,
       col.by="purple",
       addrow.overall=TRUE,
       test.subgroup.common=FALSE,
       test.subgroup.random=FALSE)
# Out:
# plot without title

# %% [markdown]
# **Pericarditis following heterologous vaccination**

# %% [markdown]
# Female

# %%
ref1_f<-ref1[ref1$status %in% c("SP","SP-SP","SP-SP-PZ") & ref1$sex == "Female",]
ref1_f$age[ref1_f$age=="5-11"]<-"  5-11"
ref1_f$Age<-paste0(ref1_f$age," yr")
ref1_f$Age<-factor(ref1_f$Age,levels = c("  5-11 yr","12-17 yr","18-40 yr"))
ref1_f<- ref1_f%>% arrange(status,sex,Age)
ref1_f$Dose<-str_count(ref1_f$status,"-")+1

# %%
hetero_peri_female_meta<-metainc(event.e=n_peri,
                     time.e=N,
                     event.c=n_peri_c,
                     time.c=N_c,
                     studlab=Age,
                     data=ref1_f,
                     sm="IRR",
                     incr = 0,
                     method ="MH",
                     method.incr = "only0",
                     byvar = Dose,
                     common = TRUE,
                     random = TRUE)

# %% [markdown]
# !!! No event

# %%
forest(hetero_peri_female_meta,
       order = ref1_m$Age,
       col.square = "green",
       col.square.lines = "green",
       col.diamond.random = "black",
       col.diamond.lines.random = "black",
       allstudies = TRUE,
       text.common = "IRR (fixed)",
       text.random = "IRR (random)",
       leftlabs=c("Dose-age","Event (n)","Total (N•Month)","Event (n)","Total (N•Month)"),
       lab.e="Homologous vaccination",
       lab.c="Reference",
       label.right="Higher risk in vaccine group",
       col.label.right="red",
       label.left="Higher risk in reference group",
       col.label.left="blue",
       hetstat=TRUE,
       digits.mean=2,
       digits.sd=2,
       digits.weight = 0,
       weight.study = "random",
       overall = TRUE,
       col.by="purple",
       addrow.overall=TRUE,
       test.subgroup.common=FALSE,
       test.subgroup.random=FALSE)
# Out:
# Error in if (!is.na(TE) && ((min <= TE & TE <= max) | (min <= lower & : missing value where TRUE/FALSE needed
# Traceback:
#
# 1. forest(hetero_peri_female_meta, order = ref1_m$Age, col.square = "green",
#  .     col.square.lines = "green", col.diamond.random = "black",
#  .     col.diamond.lines.random = "black", allstudies = TRUE, text.common = "IRR (fixed)",
#  .     text.random = "IRR (random)", leftlabs = c("Dose-age", "Event (n)",
#  .         "Total (N•Month)", "Event (n)", "Total (N•Month)"),
#  .     lab.e = "Homologous vaccination", lab.c = "Reference", label.right = "Higher risk in vaccine group",
#  .     col.label.right = "red", label.left = "Higher risk in reference group",
#  .     col.label.left = "blue", hetstat = TRUE, digits.mean = 2,
#  .     digits.sd = 2, digits.weight = 0, weight.study = "random",
#  .     overall = TRUE, col.by = "purple", addrow.overall = TRUE,
#  .     test.subgroup.common = FALSE, test.subgroup.random = FALSE)
# 2. forest.meta(hetero_peri_female_meta, order = ref1_m$Age, col.square = "green",
#  .     col.square.lines = "green", col.diamond.random = "black",
#  .     col.diamond.lines.random = "black", allstudies = TRUE, text.common = "IRR (fixed)",
#  .     text.random = "IRR (random)", leftlabs = c("Dose-age", "Event (n)",
#  .         "Total (N•Month)", "Event (n)", "Total (N•Month)"),
#  .     lab.e = "Homologous vaccination", lab.c = "Reference", label.right = "Higher risk in vaccine group",
#  .     col.label.right = "red", label.left = "Higher risk in reference group",
#  .     col.label.left = "blue", hetstat = TRUE, digits.mean = 2,
#  .     digits.sd = 2, digits.weight = 0, weight.study = "random",
#  .     overall = TRUE, col.by = "purple", addrow.overall = TRUE,
#  .     test.subgroup.common = FALSE, test.subgroup.random = FALSE)
# 3. draw.forest(col.forest, j)
# 4. draw.ci.diamond(x$eff[i], x$low[i], x$upp[i], x$sizes[i], x$range[1],
#  .     x$range[2], x$col.diamond[i], x$col.diamond.lines[i])
# plot without title

# %% [markdown]
# Male

# %%
ref1_m<-ref1[ref1$status %in% c("SP","SP-SP","SP-SP-PZ") & ref1$sex == "Male",]
ref1_m$Age<-paste0(ref1_m$age," yr")
ref1_m$Age[ref1_m$Age=="5-11 yr"]<-"  5-11 yr"
ref1_m$Age<-factor(ref1_m$Age,levels = c("  5-11 yr","12-17 yr","18-40 yr"))
ref1_m<- ref1_m%>% arrange(status,sex,Age)
ref1_m<-ref1_m[ref1_m$n_peri != 0 & ref1_m$n_peri_c != 0,]
ref1_m$Dose<-str_count(ref1_m$status,"-")+1

# %%
hetero_peri_male_meta<-metainc(event.e=n_peri,
                     time.e=N,
                     event.c=n_peri_c,
                     time.c=N_c,
                     studlab=Age,
                     data=ref1_m,
                     sm="IRR",
                     incr = 0,
                     method ="MH",
                     method.incr = "only0",
                     byvar = Dose,
                     common = TRUE,
                     random = TRUE)

# %%
forest(hetero_peri_male_meta,
       order = ref1_m$Age,
       col.square = "green",
       col.square.lines = "green",
       col.diamond.random = "black",
       col.diamond.lines.random = "black",
       allstudies = TRUE,
       text.common = "IRR (fixed)",
       text.random = "IRR (random)",
       leftlabs=c("Dose-age","Event (n)","Total (N•Month)","Event (n)","Total (N•Month)"),
       lab.e="Homologous vaccination",
       lab.c="Reference",
       label.right="Higher risk in vaccine group",
       col.label.right="red",
       label.left="Higher risk in reference group",
       col.label.left="blue",
       hetstat=TRUE,
       digits.mean=2,
       digits.sd=2,
       digits.weight = 0,
       weight.study = "random",
       overall = TRUE,
       col.by="purple",
       addrow.overall=TRUE,
       test.subgroup.common=FALSE,
       test.subgroup.random=FALSE)
# Out:
# plot without title

# %% [markdown]
# ## **SARS-CoV-2 infection**

# %% [markdown]
# **Myocarditis following SARS-CoV-2 infection**

# %%
ref_inf<-ref1[ref1$status=="infected",]
ref_inf$age[ref_inf$age=="5-11"]<-"  5-11"
ref_inf$Age<-paste0(ref_inf$age," yr")
ref_inf$Age<-factor(ref_inf$Age,levels = c("  5-11 yr","12-17 yr","18-40 yr"))
ref_inf<- ref_inf%>% arrange(status,sex,Age)

# %%
myo_inf_meta<-metainc(event.e=n_myo,
                     time.e=N,
                     event.c=n_myo_c,
                     time.c=N_c,
                     studlab=Age,
                     data=ref_inf,
                     sm="IRR",
                     incr = 0,
                     method ="MH",
                     method.incr = "only0",
                     byvar = sex,
                     common = TRUE,
                     random = TRUE)

# %%
forest(myo_inf_meta,
       order = ref_inf$Age,
       col.square = "green",
       col.square.lines = "green",
       col.diamond.random = "black",
       col.diamond.lines.random = "black",
       allstudies = TRUE,
       text.common = "IRR (fixed)",
       text.random = "IRR (random)",
       leftlabs=c("Sex-age","Event (n)","Total (N•Month)","Event (n)","Total (N•Month)"),
       lab.e="SARS-CoV-2 Infection",
       lab.c="Reference",
       label.right="Higher risk in infection group",
       col.label.right="red",
       label.left="Higher risk in reference group",
       col.label.left="blue",
       hetstat=TRUE,
       digits.mean=2,
       digits.sd=2,
       digits.weight = 0,
       weight.study = "random",
       overall = TRUE,
       col.by="purple",
       addrow.overall=TRUE,
       test.subgroup.common=FALSE,
       test.subgroup.random=FALSE)
# Out:
# plot without title

# %% [markdown]
# **Pericarditis following SARS-CoV-2 infection**

# %%
ref_inf<-ref1[ref1$status=="infected",]
ref_inf$age[ref_inf$age=="5-11"]<-"  5-11"
ref_inf$Age<-paste0(ref_inf$age," yr")
ref_inf$Age<-factor(ref_inf$Age,levels = c("  5-11 yr","12-17 yr","18-40 yr"))
ref_inf<- ref_inf%>% arrange(status,sex,Age)
ref_inf<-ref_inf[ref_inf$n_peri != 0 & ref_inf$n_peri_c != 0,]

# %%
peri_inf_meta<-metainc(event.e=n_peri,
                      time.e=N,
                      event.c=n_peri_c,
                      time.c=N_c,
                      studlab=Age,
                      data=ref_inf,
                      sm="IRR",
                      incr = 0,
                      method ="MH",
                      method.incr = "only0",
                      byvar = sex,
                      common = TRUE,
                      random = TRUE)

# %%
forest(peri_inf_meta,
       order = ref_inf$Age,
       col.square = "green",
       col.square.lines = "green",
       col.diamond.random = "black",
       col.diamond.lines.random = "black",
       allstudies = TRUE,
       text.common = "IRR (fixed)",
       text.random = "IRR (random)",
       leftlabs=c("Sex-age","Event (n)","Total (N•Month)","Event (n)","Total (N•Month)"),
       lab.e="SARS-CoV-2 infection",
       lab.c="Reference",
       label.right="Higher risk in infection group",
       col.label.right="red",
       label.left="Higher risk in reference group",
       col.label.left="blue",
       hetstat=TRUE,
       digits.mean=2,
       digits.sd=2,
       digits.weight = 0,
       weight.study = "random",
       overall = TRUE,
       col.by="purple",
       addrow.overall=TRUE,
       test.subgroup.common=FALSE,
       test.subgroup.random=FALSE)
# Out:
# plot without title
